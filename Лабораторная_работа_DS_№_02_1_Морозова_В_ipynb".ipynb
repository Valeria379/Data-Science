# %% [markdown]
# <a href="https://colab.research.google.com/github/Valeria379/Valeria-Morozova/blob/main/%D0%9B%D0%B0%D0%B1%D0%BE%D1%80%D0%B0%D1%82%D0%BE%D1%80%D0%BD%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_DS_%E2%84%96_02_1_%D0%9C%D0%BE%D1%80%D0%BE%D0%B7%D0%BE%D0%B2%D0%B0_%D0%92_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Лабораторная работа 2-1

# %% [markdown]
# ## 2.1.1: Множества
#
# Напишите функцию, которая находит пересечение двух множеств и печатает их.
# Инициализируйте два множества, например, значениями {13, 25, 37, 45, 13} и {14, 25, 38, 8, 45} и вызовите  функцию.

# %% [markdown]
# Инициализируем два множества

# %%
set1 = {13, 25, 37, 45, 13}
set2 = {14, 25, 38, 8, 45}

# %% [markdown]
# Напишем функцию и вызовем ее

# %%
def find_intersection(set1, set2):
  result = set1.intersection(set2)
  return result

print("Множество №1:", set1)
print("Множество №2:", set2)
find_intersection(set1, set2)
# Out:
# Множество №1: {25, 13, 37, 45}
# Множество №2: {38, 8, 25, 45, 14}
# {25, 45}

# %% [markdown]
# ## 2.1.2: Dictionaries
#
# * Создайте словарь с двухбуквенными кодами двух федеральных округов России и полными названиями, например, ЦТ: 	Центральный, ЮЖ: Южный.
# * После первоначального создания словаря добавьте в словарь еще два округа.
# * Создайте второй словарь, который сопоставляет коды федеральных округов России с массивом городов в этом округе, например, ЦТ: [Москва, Тверь, Химки, Мытищи].
# * Напишите функцию, которая принимает код федеральных округов, печатает полное название округа и выводит список городов в этом округе.

# %% [markdown]
# Создадим словарь с двухбуквенными кодами федеральных округов

# %%
fed_district = {"ЦТ":"Центральный", "ЮЖ":"Южный"}
fed_district
# Out:
# {'ЦТ': 'Центральный', 'ЮЖ': 'Южный'}

# %% [markdown]
# Добавим еще 2 округа

# %%
fed_district ["СЗ"] = "Северо-западный"
fed_district ["ПФО"] = "Приволжский"
fed_district
# Out:
# {'ЦТ': 'Центральный',
#  'ЮЖ': 'Южный',
#  'СЗ': 'Северо-западный',
#  'ПФО': 'Приволжский'}

# %% [markdown]
# Создадим второй словарь, который сопоставляет коды федеральных округов России с массивом городов в этом округе

# %%
county_and_cities = {"ЦТ":["Москва", "Тверь", "Химки", "Мытищи"], "ЮЖ":["Ростов-на-Дону", "Севастополь", "Волгоград", "Астрахань"], "СЗ":["Псков", "Великий Новгород", "Санкт-Петербург", "Калининград"], "ПФО":["Нижний Новгород", "Йошкар-Ола", "Казань", "Свияжск"]}
county_and_cities
# Out:
# {'ЦТ': ['Москва', 'Тверь', 'Химки', 'Мытищи'],
#  'ЮЖ': ['Ростов-на-Дону', 'Севастополь', 'Волгоград', 'Астрахань'],
#  'СЗ': ['Псков', 'Великий Новгород', 'Санкт-Петербург', 'Калининград'],
#  'ПФО': ['Нижний Новгород', 'Йошкар-Ола', 'Казань', 'Свияжск']}

# %% [markdown]
# Напишем функцию, которая принимает код федеральных округов, печатает полное название округа и выводит список городов в этом округе.

# %%
def function(cod_okruga):
  if cod_okruga in fed_district:
    print("Наименование округа:", fed_district[cod_okruga])
    print("Список городов:", county_and_cities[cod_okruga])
  else:
    print("Такого округа нет")
function("ЮЖ")
# Out:
# Наименование округа: Южный
# Список городов: ['Ростов-на-Дону', 'Севастополь', 'Волгоград', 'Астрахань']

# %% [markdown]
# ## 2.1.3: Objects
#
# Создайте класс `Pet` с параметрами `name, pronoun, animal,` и `pet_response`.
#
# Добавьте метод `pet()`, который печатает ответ, состоящий из элементов, например:
#
# ` Лейла — кошка. Если ее погладить, Лейла мурчит».`
# ` Скаут — собака. Если его погладить, Скаут виляет хвостом.`

# %%
class Pet:
  def __init__(self, name, pronoun, animal, pet_response):
    self.name = name
    self.pronoun = pronoun
    self.animal = animal
    self.pet_response = pet_response

  def pet(self):
    print(self.name, self.pronoun, self.animal, self.pet_response)

# %% [markdown]
# Вот несколько примеров вызовов:

# %%
layla = Pet("Layla", "her", "cat", "purrs")
scout = Pet("Scout", "her", "dog", "wags her tail")

layla.pet()
scout.pet()
# Out:
# Layla her cat purrs
# Scout her dog wags her tail

# %%
class Pet:
  def __init__(self, name = "Лейла", animal = "- кошка", pronoun = "она", pet_response = "мурчит"):
    self.name = name
    self.animal = animal
    self.pronoun = pronoun
    self.pet_response = pet_response

  def pet(self):
    print(self.name, self.animal, self.pronoun, self.pet_response)

# %%
layla = Pet()
layla.pet()
# Out:
# Лейла - кошка она мурчит

# %%
class Pet:
  def __init__(self, name = "Скаут", animal = "- собака", pronoun = "он", pet_response = "виляет хвостом"):
    self.name = name
    self.animal = animal
    self.pronoun = pronoun
    self.pet_response = pet_response

  def pet(self):
    print(self.name, self.animal, self.pronoun, self.pet_response)

# %%
scout = Pet()
scout.pet()
# Out:
# Скаут - собака он виляет хвостом

# %% [markdown]
# ## 2.1.4: Pandas Series

# %% [markdown]
# Создайте `pandas series`, используя приведенные ниже списки, содержащие названия команд [Российской премьер-лиги](https://ru.wikipedia.org/wiki/%D0%A0%D0%BE%D1%81%D1%81%D0%B8%D0%B9%D1%81%D0%BA%D0%B0%D1%8F_%D0%BF%D1%80%D0%B5%D0%BC%D1%8C%D0%B5%D1%80-%D0%BB%D0%B8%D0%B3%D0%B0) и количество выигранных ими кубка премьер-лиги. Используйте имена как индексы, а победы как данные.
#
#   * После создания списка отсортируйте данные в алфавитном порядке по индексу.
#   * Распечатать обзор статистических свойств ряда. Каково среднее количество побед?
#   * Отфильтровать все команды, выигравшие менее четырех кубков премьер-лиги.
#   * В футбольной команде 11 игроков. Обновите данные, чтобы вместо количества чемпионатов,  отражалось количество побед.
#   * Предположим, что каждая  победа приносила 50 000 долларов США. Обновите данные, чтобы они содержали строку суммы в долларах, включая знак \$. Например, для `Локомотив` это будет соответствовать:
#   ```
#   Тренер Юрий Сёмин  Локомотив $ 600000
#   ```

# %%
teams = ["Юрий Сёмин («Локомотив»)",
         "Олег Романцев («Спартак»)",
         "Сергей Семак («Зенит»)",
         "Валерий Газзаев («Спартак-Алания»)",
         "Леонид Слуцкий (ЦСКА)",
         "Курбан Бердыев («Рубин»)",
         "Лучано Спаллетти («Зенит»)",
         "Андре Виллаш-Боаш («Зенит»)",
         "Дик Адвокат («Зенит»)",
         "Массимо Каррера («Спартак»)",
         "Зико (ЦСКА)",
         "Георгий Ярцев («Спартак»)"]
wins = [12,11,10,10,7,5,4,3,2,2,1,1]

# %%
import pandas as pd

# %%
def toDollars(amount):
    return "$ " + str(amount)

toDollars(15)
# Out:
# '$ 15'

# %% [markdown]
# Создаим pandas series

# %%
team_wins = pd.Series([12,11,10,10,7,5,4,3,2,2,1,1],
                      index = ["Юрий Сёмин («Локомотив»)",
         "Олег Романцев («Спартак»)",
         "Сергей Семак («Зенит»)",
         "Валерий Газзаев («Спартак-Алания»)",
         "Леонид Слуцкий (ЦСКА)",
         "Курбан Бердыев («Рубин»)",
         "Лучано Спаллетти («Зенит»)",
         "Андре Виллаш-Боаш («Зенит»)",
         "Дик Адвокат («Зенит»)",
         "Массимо Каррера («Спартак»)",
         "Зико (ЦСКА)",
         "Георгий Ярцев («Спартак»)"])
team_wins
# Out:
# Юрий Сёмин («Локомотив»)              12
# Олег Романцев («Спартак»)             11
# Сергей Семак («Зенит»)                10
# Валерий Газзаев («Спартак-Алания»)    10
# Леонид Слуцкий (ЦСКА)                  7
# Курбан Бердыев («Рубин»)               5
# Лучано Спаллетти («Зенит»)             4
# Андре Виллаш-Боаш («Зенит»)            3
# Дик Адвокат («Зенит»)                  2
# Массимо Каррера («Спартак»)            2
# Зико (ЦСКА)                            1
# Георгий Ярцев («Спартак»)              1
# dtype: int64

# %% [markdown]
# Отсортируем данные в алфавитном порядке по индексу

# %%
sorting = team_wins.sort_index()
sorting
# Out:
# Андре Виллаш-Боаш («Зенит»)            3
# Валерий Газзаев («Спартак-Алания»)    10
# Георгий Ярцев («Спартак»)              1
# Дик Адвокат («Зенит»)                  2
# Зико (ЦСКА)                            1
# Курбан Бердыев («Рубин»)               5
# Леонид Слуцкий (ЦСКА)                  7
# Лучано Спаллетти («Зенит»)             4
# Массимо Каррера («Спартак»)            2
# Олег Романцев («Спартак»)             11
# Сергей Семак («Зенит»)                10
# Юрий Сёмин («Локомотив»)              12
# dtype: int64

# %% [markdown]
# Распечатаем обзор статистических свойств ряда

# %%
team_wins.describe()
# Out:
# count    12.000000
# mean      5.666667
# std       4.141439
# min       1.000000
# 25%       2.000000
# 50%       4.500000
# 75%      10.000000
# max      12.000000
# dtype: float64

# %% [markdown]
# Рассчитаем среднее количество побед

# %%
sredne = team_wins.mean()
round(sredne, 2)
# Out:
# 5.67

# %% [markdown]
# Отфильтруем все команды, выигравшие менее четырех кубков премьер-лиги

# %%
filter = team_wins[team_wins < 4]
filter
# Out:
# Андре Виллаш-Боаш («Зенит»)    3
# Дик Адвокат («Зенит»)          2
# Массимо Каррера («Спартак»)    2
# Зико (ЦСКА)                    1
# Георгий Ярцев («Спартак»)      1
# dtype: int64

# %% [markdown]
# Импортируем библиотеки для парсинга таблицы

# %%
import requests
import pandas as pd
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %% [markdown]
# Выгрузим таблицу, чтобы обновить данные

# %%
url = 'https://ru.wikipedia.org/wiki/Российская_премьер-лига'
soup = BeautifulSoup(requests.get(url).text, 'html.parser')
trener_table = soup.findAll('table', class_='wikitable')[2]
req=requests.get(url)
data=pd.read_html(str(trener_table))
df=data[0]

# %%
df
# Out:
#      №                                    Тренер  Всего  Чемпионат  Кубок  \
# 0    1                  Юрий Сёмин («Локомотив»)     12          3      6
# 1    2                 Олег Романцев («Спартак»)     11          8      3
# 2    3                    Сергей Семак («Зенит»)     10          5      1
# 3    4  Валерий Газзаев («Спартак-Алания», ЦСКА)     10          4      4
# 4    5                     Леонид Слуцкий (ЦСКА)      7          3      2
# 5    6                  Курбан Бердыев («Рубин»)      5          2      1
# 6    7                Лучано Спаллетти («Зенит»)      4          2      1
# 7    8               Андре Виллаш-Боаш («Зенит»)      3          1      1
# 8    9                     Дик Адвокат («Зенит»)      2          1      0
# 9    9               Массимо Каррера («Спартак»)      2          1      0
# 10  11                               Зико (ЦСКА)      2          0      1
# 11  12                 Георгий Ярцев («Спартак»)      1          1      0
# ...

# %% [markdown]
# Уберем столбец "Чемпионат"

# %%
del df['Чемпионат']
df
# Out:
#      №                                    Тренер  Всего  Кубок  Кубок лиги  \
# 0    1                  Юрий Сёмин («Локомотив»)     12      6           0
# 1    2                 Олег Романцев («Спартак»)     11      3           0
# 2    3                    Сергей Семак («Зенит»)     10      1           0
# 3    4  Валерий Газзаев («Спартак-Алания», ЦСКА)     10      4           0
# 4    5                     Леонид Слуцкий (ЦСКА)      7      2           0
# 5    6                  Курбан Бердыев («Рубин»)      5      1           0
# 6    7                Лучано Спаллетти («Зенит»)      4      1           0
# 7    8               Андре Виллаш-Боаш («Зенит»)      3      1           0
# 8    9                     Дик Адвокат («Зенит»)      2      0           0
# 9    9               Массимо Каррера («Спартак»)      2      0           0
# 10  11                               Зико (ЦСКА)      2      1           0
# ...

# %%
del df['Всего']
df
# Out:
#      №                                    Тренер  Кубок  Кубок лиги  \
# 0    1                  Юрий Сёмин («Локомотив»)      6           0
# 1    2                 Олег Романцев («Спартак»)      3           0
# 2    3                    Сергей Семак («Зенит»)      1           0
# 3    4  Валерий Газзаев («Спартак-Алания», ЦСКА)      4           0
# 4    5                     Леонид Слуцкий (ЦСКА)      2           0
# 5    6                  Курбан Бердыев («Рубин»)      1           0
# 6    7                Лучано Спаллетти («Зенит»)      1           0
# 7    8               Андре Виллаш-Боаш («Зенит»)      1           0
# 8    9                     Дик Адвокат («Зенит»)      0           0
# 9    9               Массимо Каррера («Спартак»)      0           0
# 10  11                               Зико (ЦСКА)      1           0
# 11  12                 Георгий Ярцев («Спартак»)      0           0
# 12  13                  Юрий Миронов («Торпедо»)      1           0
# ...

# %% [markdown]
# Расчитаем суммарное количество побед

# %%
df['Количество_побед'] = df[['Кубок', 'Кубок лиги', 'Суперкубок']].sum(axis=1)
df
# Out:
#      №                                    Тренер  Кубок  Кубок лиги  \
# 0    1                  Юрий Сёмин («Локомотив»)      6           0
# 1    2                 Олег Романцев («Спартак»)      3           0
# 2    3                    Сергей Семак («Зенит»)      1           0
# 3    4  Валерий Газзаев («Спартак-Алания», ЦСКА)      4           0
# 4    5                     Леонид Слуцкий (ЦСКА)      2           0
# 5    6                  Курбан Бердыев («Рубин»)      1           0
# 6    7                Лучано Спаллетти («Зенит»)      1           0
# 7    8               Андре Виллаш-Боаш («Зенит»)      1           0
# 8    9                     Дик Адвокат («Зенит»)      0           0
# 9    9               Массимо Каррера («Спартак»)      0           0
# 10  11                               Зико (ЦСКА)      1           0
# 11  12                 Георгий Ярцев («Спартак»)      0           0
# 12  13                  Юрий Миронов («Торпедо»)      1           0
# ...

# %% [markdown]
# Обновим данные, чтобы они содержали строку суммы в долларах, включая знак $, учитывая, что за одну победу платят  50000

# %%
df = df.assign(Sum_dollars = df.Количество_побед * 50000)
df
# Out:
#      №                                    Тренер  Кубок  Кубок лиги  \
# 0    1                  Юрий Сёмин («Локомотив»)      6           0
# 1    2                 Олег Романцев («Спартак»)      3           0
# 2    3                    Сергей Семак («Зенит»)      1           0
# 3    4  Валерий Газзаев («Спартак-Алания», ЦСКА)      4           0
# 4    5                     Леонид Слуцкий (ЦСКА)      2           0
# 5    6                  Курбан Бердыев («Рубин»)      1           0
# 6    7                Лучано Спаллетти («Зенит»)      1           0
# 7    8               Андре Виллаш-Боаш («Зенит»)      1           0
# 8    9                     Дик Адвокат («Зенит»)      0           0
# 9    9               Массимо Каррера («Спартак»)      0           0
# 10  11                               Зико (ЦСКА)      1           0
# 11  12                 Георгий Ярцев («Спартак»)      0           0
# 12  13                  Юрий Миронов («Торпедо»)      1           0
# ...

# %% [markdown]
# Добавим знак доллара

# %%
def add_dollar(Sum_dollars):
    return '$' + str(Sum_dollars)

# %%
df['Sum_dollars'] = df['Sum_dollars'].apply(add_dollar)
df
# Out:
#      №                                    Тренер  Кубок  Кубок лиги  \
# 0    1                  Юрий Сёмин («Локомотив»)      6           0
# 1    2                 Олег Романцев («Спартак»)      3           0
# 2    3                    Сергей Семак («Зенит»)      1           0
# 3    4  Валерий Газзаев («Спартак-Алания», ЦСКА)      4           0
# 4    5                     Леонид Слуцкий (ЦСКА)      2           0
# 5    6                  Курбан Бердыев («Рубин»)      1           0
# 6    7                Лучано Спаллетти («Зенит»)      1           0
# 7    8               Андре Виллаш-Боаш («Зенит»)      1           0
# 8    9                     Дик Адвокат («Зенит»)      0           0
# 9    9               Массимо Каррера («Спартак»)      0           0
# 10  11                               Зико (ЦСКА)      1           0
# 11  12                 Георгий Ярцев («Спартак»)      0           0
# 12  13                  Юрий Миронов («Торпедо»)      1           0
# ...
